# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({
    "lines.color": "white",
    "patch.edgecolor": "white",
    "text.color": "black",
    "axes.facecolor": "white",
    "axes.edgecolor": "lightgray",
    "axes.labelcolor": "white",
    "xtick.color": "white",
    "ytick.color": "white",
    "grid.color": "lightgray",
    "figure.facecolor": "black",
    "figure.edgecolor": "black",
    "savefig.facecolor": "black",
    "savefig.edgecolor": "black",
    'font.family' : 'Consolas',
    'font.weight' : 'bold',
    'font.size'   : 13,
    'figure.figsize': (8, 8)})
plt.style.use("dark_background")
plt.clf()

# %%
import json

# %%
import pandas as pd

# %%
df = pd.read_csv('bq-results-20191101-151326-gpk72938slue.csv')

# %%
df.head()
# Out:
#    fees_per_byte  txn_cnt
# 0           5398        2
# 1           3901        4
# 2           1313       16
# 3           2305        2
# 4           7343        1

# %%
sampled = df.sample(6000)

# %%
fees = np.log(np.array(df.sort_values(by='txn_cnt', ascending=False)['fees_per_byte']) + 1.0)
np.max(fees)
# Out:
# 13.69550330055961

# %%
cnts = np.log(np.array(df.sort_values(by='txn_cnt', ascending=False)['txn_cnt']) + 1.0)
np.max(cnts)
# Out:
# 16.056972304799572

# %%
plt.clf()
plt.scatter(fees, cnts, color='cyan')

# %%
plt.show()

# %%
df.head()
# Out:
#    fees_per_byte  txn_cnt
# 0           5398        2
# 1           3901        4
# 2           1313       16
# 3           2305        2
# 4           7343        1

# %%
df.sort_values(by='gas_price')
# Out:
#                gas_price  txn_cnt
# 2844                   0   121023
# 3789                   1      117
# 561096                 2        7
# 546580                 3        4
# 531717                 4        3
# ...                  ...      ...
# 88574    900000000010000        1
# 185843  1000000000000000        1
# 239609  1029227161891400        1
# 226147  3740192478632060        1
# 133355  5287166707489509        1
#
# [566022 rows x 2 columns]

# %%
df.sort_values(by='txn_cnt',ascending=False)['gas_price']
# Out:
# 25342     20000000000
# 28257      1000000000
# 8576      10000000000
# 22584     30000000000
# 16960     40000000000
#              ...
# 215015    23019384454
# 215014    14237602485
# 215013    16363397309
# 215012    56658593750
# 283011    11897821171
# Name: gas_price, Length: 566022, dtype: int64

# %%
non_one = df[df['fees_per_byte'] > 1]

# %%
plt.clf()

# %%
cnts = np.array(non_one['txn_cnt'])

# %%
fees = np.array(non_one['fees_per_byte'])

# %%
plt.clf()
plt.bar(fees, cnts, color='cyan', width=2000)
# Out:
# <BarContainer object of 6117 artists>
